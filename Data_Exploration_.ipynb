# %% [markdown]
# <a href="https://colab.research.google.com/github/AnushkaShrivastava28/Airbnd-Data-Analytics-Project/blob/main/Data_Exploration_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Exploration using SQLite and Pandas Dataframe

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import sqlite3

# %% [markdown]
# **Importing Dataset**

# %%
data = pd.read_csv('Airbnb.csv')
data.head()
# Out:
#     id            name  host_id       host_name neighbourhood_group  \
# 0  362      Kavya Iyer    88018      Kavya Iyer              Jaipur
# 1   74  Karan Malhotra    98647  Karan Malhotra     Central Kolkata
# 2  375     Rohan Patel    78656     Rohan Patel              Jaipur
# 3  156       Amit Jain    98150       Amit Jain             Udaipur
# 4  105    Pooja Mishra    35430    Pooja Mishra              Bhopal
#
#   neighbourhood   latitude  longitude        room_type    price  \
# 0      C Scheme  26.879660  75.825309     Private room   2356.0
# 1   Park Street  22.620204  88.292602  Entire home/apt   9209.0
# 2    Mansarovar  26.881098  75.763871  Entire home/apt  10148.0
# 3     Hathi Pol  24.592350  73.662297     Private room   1336.0
# 4      MP Nagar  23.343002  77.448109  Entire home/apt  12236.0
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               4                 67  2023-06-24               2.34
# ...

# %% [markdown]
# **Connecting sqlite database**

# %%
conn = sqlite3.connect('airbnb_database.db')#this is database name

# %%
#now lets make an table and import all data in sqlite3
# if exist mean if before table hai to replace and also index false mean index ko load mat kro wrna ek extra column add
data.to_sql('airbnb_table', conn, if_exists='replace', index=False)
# Out:
# 500

# %%
query = 'SELECT * From airbnb_table'
pd.read_sql(query, conn)
# Out:
#       id            name  host_id       host_name neighbourhood_group  \
# 0    362      Kavya Iyer    88018      Kavya Iyer              Jaipur
# 1     74  Karan Malhotra    98647  Karan Malhotra     Central Kolkata
# 2    375     Rohan Patel    78656     Rohan Patel              Jaipur
# 3    156       Amit Jain    98150       Amit Jain             Udaipur
# 4    105    Pooja Mishra    35430    Pooja Mishra              Bhopal
# ..   ...             ...      ...             ...                 ...
# 495  107      Sneha Nair    22021      Sneha Nair           Ahmedabad
# 496  271      Sneha Nair    84057      Sneha Nair     Western Suburbs
# 497  349     Meera Menon    30174     Meera Menon             Gurgaon
# 498  436       Amit Jain    62692       Amit Jain               Noida
# 499  103     Rahul Mehta    30308     Rahul Mehta     South Bengaluru
#
#     neighbourhood   latitude  longitude        room_type    price  \
# ...

# %%
query = 'SELECT * FROM airbnb_table'
pd.read_sql(query, conn)
# Out:
#       id            name  host_id       host_name neighbourhood_group  \
# 0    362      Kavya Iyer    88018      Kavya Iyer              Jaipur
# 1     74  Karan Malhotra    98647  Karan Malhotra     Central Kolkata
# 2    375     Rohan Patel    78656     Rohan Patel              Jaipur
# 3    156       Amit Jain    98150       Amit Jain             Udaipur
# 4    105    Pooja Mishra    35430    Pooja Mishra              Bhopal
# ..   ...             ...      ...             ...                 ...
# 495  107      Sneha Nair    22021      Sneha Nair           Ahmedabad
# 496  271      Sneha Nair    84057      Sneha Nair     Western Suburbs
# 497  349     Meera Menon    30174     Meera Menon             Gurgaon
# 498  436       Amit Jain    62692       Amit Jain               Noida
# 499  103     Rahul Mehta    30308     Rahul Mehta     South Bengaluru
#
#     neighbourhood   latitude  longitude        room_type    price  \
# ...

# %% [markdown]
# **WHERE Room type = Private room**

# %%
query = 'SELECT * FROM airbnb_table WHERE room_type = "Private room"'
pd.read_sql(query, conn)
# Out:
#       id          name  host_id     host_name neighbourhood_group  \
# 0    362    Kavya Iyer    88018    Kavya Iyer              Jaipur
# 1    156     Amit Jain    98150     Amit Jain             Udaipur
# 2    395     Amit Jain    98892     Amit Jain             Lucknow
# 3    378   Simran Kaur    74414          None     Central Chennai
# 4    125  Vikram Joshi    42847  Vikram Joshi          Chandigarh
# ..   ...           ...      ...           ...                 ...
# 162  331    Kavya Iyer    73782    Kavya Iyer             Udaipur
# 163  215   Meera Menon    35614   Meera Menon           North Goa
# 164  467   Simran Kaur    49343   Simran Kaur             Lucknow
# 165   72   Priya Verma    94717   Priya Verma              Jaipur
# 166  349   Meera Menon    30174   Meera Menon             Gurgaon
#
#      neighbourhood   latitude  longitude     room_type   price  \
# 0         C Scheme  26.879660  75.825309  Private room  2356.0
# ...

# %% [markdown]
# **query to find neighbourhood = Mahanagar**

# %%
query = 'SELECT * FROM airbnb_table WHERE neighbourhood = "Mahanagar" '
pd.read_sql(query, conn)
# Out:
#      id          name  host_id     host_name neighbourhood_group  \
# 0   372   Simran Kaur    53721   Simran Kaur             Lucknow
# 1   492    Kavya Iyer    38059    Kavya Iyer             Lucknow
# 2   498   Priya Verma    94448   Priya Verma             Lucknow
# 3    78  Pooja Mishra    81364          None             Lucknow
# 4    12  Pooja Mishra    95180  Pooja Mishra             Lucknow
# 5   132   Priya Verma    57964   Priya Verma             Lucknow
# 6   484   Simran Kaur    18942   Simran Kaur             Lucknow
# 7   181  Pooja Mishra    96193  Pooja Mishra             Lucknow
# 8   391   Simran Kaur    83745   Simran Kaur             Lucknow
# 9   179    Nikhil Rao    13527    Nikhil Rao             Lucknow
# 10  136    Sahil Khan    95929    Sahil Khan             Lucknow
# 11   92  Ananya Singh    53007  Ananya Singh             Lucknow
#
#    neighbourhood   latitude  longitude        room_type    price  \
# ...

# %% [markdown]
# **All details with availability_365 exist**

# %%
# find all details with availability _365 exist
querr = 'SELECT * FROM airbnb_table WHERE availability_365 = 365'
pd.read_sql(query, conn)
# Out:
#      id          name  host_id     host_name neighbourhood_group  \
# 0   372   Simran Kaur    53721   Simran Kaur             Lucknow
# 1   492    Kavya Iyer    38059    Kavya Iyer             Lucknow
# 2   498   Priya Verma    94448   Priya Verma             Lucknow
# 3    78  Pooja Mishra    81364          None             Lucknow
# 4    12  Pooja Mishra    95180  Pooja Mishra             Lucknow
# 5   132   Priya Verma    57964   Priya Verma             Lucknow
# 6   484   Simran Kaur    18942   Simran Kaur             Lucknow
# 7   181  Pooja Mishra    96193  Pooja Mishra             Lucknow
# 8   391   Simran Kaur    83745   Simran Kaur             Lucknow
# 9   179    Nikhil Rao    13527    Nikhil Rao             Lucknow
# 10  136    Sahil Khan    95929    Sahil Khan             Lucknow
# 11   92  Ananya Singh    53007  Ananya Singh             Lucknow
#
#    neighbourhood   latitude  longitude        room_type    price  \
# ...

# %% [markdown]
# **Closing the connection**

# %%
conn.close()

# %% [markdown]
# **Reconnecting to SQLite Database**

# %%
conn = sqlite3.connect('airbnb_database.db')

# %% [markdown]
# # SQL Query With Pandas Dataframe

# %%
pip install pandasql
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26867 sha256=fb34e1923095b872add667e4bba4f6c310ad2f295afd17d534180396a0ebcc79
#   Stored in directory: /root/.cache/pip/wheels/b4/d0/8c/a6b366870bf041849cd96e03b71641e082f8d6456269b603b7
# Successfully built pandasql
# ...

# %%
import pandas as pd
from pandasql import sqldf

# %%
data = pd.read_csv('Airbnb.csv')

# %%
#create the dtaframe df= pd.DataFrame({'Name' : ['John','Bob']
#etc etc }) but i am choosing difficult one

#lets define the query
query = ("select * from data")

#Execute the sql query on data frame
#result = sqldf(query)
#result by this also will get same value what we wanted

sqldf(query)
# Out:
#       id            name  host_id       host_name neighbourhood_group  \
# 0    362      Kavya Iyer    88018      Kavya Iyer              Jaipur
# 1     74  Karan Malhotra    98647  Karan Malhotra     Central Kolkata
# 2    375     Rohan Patel    78656     Rohan Patel              Jaipur
# 3    156       Amit Jain    98150       Amit Jain             Udaipur
# 4    105    Pooja Mishra    35430    Pooja Mishra              Bhopal
# ..   ...             ...      ...             ...                 ...
# 495  107      Sneha Nair    22021      Sneha Nair           Ahmedabad
# 496  271      Sneha Nair    84057      Sneha Nair     Western Suburbs
# 497  349     Meera Menon    30174     Meera Menon             Gurgaon
# 498  436       Amit Jain    62692       Amit Jain               Noida
# 499  103     Rahul Mehta    30308     Rahul Mehta     South Bengaluru
#
#     neighbourhood   latitude  longitude        room_type    price  \
# ...

# %% [markdown]
# **Query WHERE room type = Share rooms**

# %%
query = ('SELECT * FROM data WHERE room_type = "Shared room" ')
sqldf(query)
# Out:
#      id          name  host_id     host_name neighbourhood_group  \
# 0    10   Simran Kaur    52487   Simran Kaur          Chandigarh
# 1   132   Priya Verma    57964   Priya Verma             Lucknow
# 2    40    Nikhil Rao    37742    Nikhil Rao             Udaipur
# 3   269      Riya Das    72684      Riya Das           North Goa
# 4     4  Arjun Kapoor    59823  Arjun Kapoor              Jaipur
# 5   359   Meera Menon    59160   Meera Menon              Bhopal
# 6   361  Arjun Kapoor    40539  Arjun Kapoor     Western Suburbs
# 7    39    Ishita Roy    26728    Ishita Roy             Udaipur
# 8   470   Rahul Mehta    79417   Rahul Mehta           North Goa
# 9   430   Simran Kaur    60387   Simran Kaur             Gurgaon
# 10  157      Riya Das    92050      Riya Das     Central Chennai
# 11  307    Sneha Nair    96652    Sneha Nair     Western Suburbs
# 12  122  Pooja Mishra    13445  Pooja Mishra             Udaipur
#
# ...

# %% [markdown]
# **Number of Room types**

# %%
query = ('SELECT room_type, count(*) FROM data GROUP BY room_type')
sqldf(query)
# Out:
#          room_type  count(*)
# 0  Entire home/apt       282
# 1       Hotel room        38
# 2     Private room       167
# 3      Shared room        13

# %%
data['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'],
#       dtype=object)

# %% [markdown]
# **Check correlation**

# %%
data.corr(numeric_only=True)
# Out:
#                                       id   host_id  latitude  longitude  \
# id                              1.000000 -0.005467  0.035125  -0.066747
# host_id                        -0.005467  1.000000  0.079421  -0.089535
# latitude                        0.035125  0.079421  1.000000   0.127047
# longitude                      -0.066747 -0.089535  0.127047   1.000000
# price                           0.036011  0.030140  0.000743  -0.133148
# minimum_nights                 -0.025859 -0.017165 -0.005450   0.037983
# number_of_reviews               0.010079  0.039819  0.027789   0.007996
# reviews_per_month               0.018539 -0.010111  0.017842  -0.079440
# calculated_host_listings_count -0.082995 -0.003394 -0.041689  -0.054975
# availability_365                0.016954 -0.048715  0.047597  -0.024874
#
#                                    price  minimum_nights  number_of_reviews  \
# id                              0.036011       -0.025859           0.010079
# ...
